# %% [markdown]
# <a href="https://colab.research.google.com/github/YashashGaurav/EDA-Indian-Startup-Analysis/blob/main/Cleaning_and_Combining_Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using the dataset uploaded on drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Disclaimer and working notes:
# 1. We downloaded all the data from the two sources and dumped it into the same folder that is referred by this code as `dataset_path`.
# 2. We renamed the file to `ISF_2021.csv` and `ISF_[month]_2022.csv` for our our convinience.
# 3. In the middle of our data cleaning process we realised that the data needed many corrections, so we did manual corrections to make the process faster using Google sheets. What and how many were those corrections? We only remember that it took us 2 hours worth of eyeballing Google Sheets. Sigh.

# %% [markdown]
# ## Imports and consts

# %%
import os
from datetime import datetime

import glob
import numpy as np
import pandas as pd
import altair as alt

# %%
print(os.getcwd())
dataset_path = '/content/drive/MyDrive/Shared Documents/DSBD - Project 1 Shared Folder/dataset'
# Out:
# /content

# %% [markdown]
# ## Load year 2021's data

# %%
isfd_2021 = pd.read_csv(dataset_path + '/ISF_2021.csv')
isfd_2021.head()
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
#
#                                         Founder/s  \
# 0                                    Ruchir Arora
# 1                          Anshul Gupta, Amit Raj
# 2                        Nitya, Chaitra Chidanand
# 3                                  Vikram Chachra
# 4  Prachi Dharani, Rohit Sukhija, Yogesh Lokhande
#
#                     Investor/s Amount(in dollars)     Stage  Month
# 0             Disrupt ADQ, QIC           35000000  Series B     12
# 1                 Tiger Global           40000000       NaN     12
# 2  Valar Ventures, IA Ventures           40000000  Series B     12
# 3                          NaN           50000000       NaN     12
# 4        Sequoia Capital India            4900000  Series A     12

# %% [markdown]
# ## Load year 2022's data

# %%
joined_files_isfd_2022 = os.path.join(dataset_path, "*2022.csv")
joined_list_isfd_2022 = glob.glob(joined_files_isfd_2022)

isfd_2022 = pd.DataFrame()
content = []

for filename in joined_list_isfd_2022:
    df = pd.read_csv(filename, index_col=None, encoding='cp1252')
    # parse month data from file name
    df['funding_month'] = datetime.strptime(filename.split('/ISF_')[1].replace('_2022.csv', ''),"%B").month
    content.append(df)

isfd_2022 = pd.concat(content)
isfd_2022.head(5)
# Out:
#     Company Name Founded    Location                             Sector  \
# 0           Dyte    2020   Bengaluru      IT Services and IT Consulting
# 1  Kirana Bazaar    2018     Gurgaon                      Oline grocery
# 2          Phool    2017      kanpur           Enviromental Engineering
# 3        Doceree    2019  Parsippany  Information Technology & Services
# 4           Acko    2016      Mumbai                   Health insurance
#
#                                         What it does  \
# 0  Dyte provides the easiest way to add real-time...
# 1  Kirana Bazaar is a neighborhood store network ...
# 2                    Phool is a biomaterial startup.
# 3  Doceree is a fully integrated programmatic ad ...
# 4  Acko is a digital insurance company with a lic...
#
#                                        Founders   Investor        Amount  \
# 0                               Felix Lee,Vivan  Multiples   $15,300,000
# 1                Abhishek Halder, Anilesh Yadav  Multiples   $32,800,000
# 2                                 Ankit Agrawal  Multiples    $9,400,000
# 3  Daleep Manhas, Harshit Jain, Stephen Hoelper  Multiples    12,000,000
# 4                                           NaN  Multiples  $458,000,000
#
#          Stage  funding_month
# 0  undisclosed              4
# 1  undisclosed              4
# 2  undisclosed              4
# 3  undisclosed              4
# 4     Series D              4

# %% [markdown]
# ## Merge datasets collected with consistent headings

# %%
print(f"ISF 2021 length- {len(isfd_2021)}")
print(f"ISF 2021 column names - {list(isfd_2021)}")

print(f"ISF 2022 length- {len(isfd_2022)}")
print(f"ISF 2022 column names - {list(isfd_2022)}")
# Out:
# ISF 2021 length- 1194
# ISF 2021 column names - ['Company/Brand', 'Founded', 'Headquarters', 'Sector', 'What it does', 'Founder/s', 'Investor/s', 'Amount(in dollars)', 'Stage', 'Month']
# ISF 2022 length- 446
# ISF 2022 column names - ['Company Name', 'Founded', 'Location', 'Sector', 'What it does', 'Founders', 'Investor', 'Amount', 'Stage', 'funding_month']

# %% [markdown]
# Rename columns to ensure they are the same and makes it easier to merge both dataframes

# %%
isfd_2021.rename(columns={
    'Company/Brand':'company_name', 
    'Founded': 'founded_year',
    'Headquarters': 'company_hq_location',
    'Sector': 'sector',
    'What it does':'company_description', 
    'Founder/s':'founders', 
    'Investor/s':'investor', 
    'Amount(in dollars)':'amount_usd',
    'Stage': 'funding_round',
    'Month': 'funding_month'
}, inplace=True)


isfd_2022.rename(columns={
    'Company Name':'company_name', 
    'Founded': 'founded_year', 
    'Location': 'company_hq_location', 
    'Sector': 'sector', 
    'What it does':'company_description', 
    'Founders': 'founders', 
    'Investor': 'investor', 
    'Amount': 'amount_usd', 
    'Stage': 'funding_round'
}
, inplace=True)

# %%
isfd_aggregated = isfd_2021.append(isfd_2022)
isfd_aggregated
# Out:
#     company_name founded_year company_hq_location  \
# 0   CollegeDekho       2015.0             Gurgaon
# 1           BOX8       2012.0              Mumbai
# 2          Simpl       2015.0           Bangalore
# 3    8i Ventures       2018.0              Mumbai
# 4      PayGlocal       2021.0           Bangalore
# ..           ...          ...                 ...
# 37           NaN          NaN                 NaN
# 38           NaN          NaN                 NaN
# 39           NaN          NaN                 NaN
# 40           NaN          NaN                 NaN
# 41           NaN          NaN                 NaN
#
#                               sector  \
# 0                         E-learning
# 1                   Food & Beverages
# 2                  Consumer Services
# 3   Venture Capital & Private Equity
# 4                 Financial Services
# ..                               ...
# 37                               NaN
# 38                               NaN
# 39                               NaN
# 40                               NaN
# 41                               NaN
#
#                                   company_description  \
# 0   Collegedekho.com is Student’s Partner, Friend ...
# 1                    India's Largest Desi Meals Brand
# 2   Simpl empowers merchants to build trusted rela...
# 3   8i is a Mumbai & Bangalore based early stage f...
# 4   PayGlocal is a FinTech solving for global paym...
# ..                                                ...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                                           founders  \
# 0                                     Ruchir Arora
# 1                           Anshul Gupta, Amit Raj
# 2                         Nitya, Chaitra Chidanand
# 3                                   Vikram Chachra
# 4   Prachi Dharani, Rohit Sukhija, Yogesh Lokhande
# ..                                             ...
# 37                                             NaN
# 38                                             NaN
# 39                                             NaN
# 40                                             NaN
# 41                                             NaN
#
#                        investor amount_usd funding_round  funding_month
# 0              Disrupt ADQ, QIC   35000000      Series B             12
# 1                  Tiger Global   40000000           NaN             12
# 2   Valar Ventures, IA Ventures   40000000      Series B             12
# 3                           NaN   50000000           NaN             12
# 4         Sequoia Capital India    4900000      Series A             12
# ..                          ...        ...           ...            ...
# 37                          NaN        NaN           NaN              5
# 38                          NaN        NaN           NaN              5
# 39                          NaN        NaN           NaN              5
# 40                          NaN        NaN           NaN              5
# 41                          NaN        NaN           NaN              5
#
# [1640 rows x 10 columns]

# %% [markdown]
# ## Cleaning the dataset

# %% [markdown]
# Removing rows that do not have a company name

# %%
isfd_aggregated = isfd_aggregated[~isfd_aggregated['company_name'].isna()]

# %%
isfd_aggregated.isna().sum()
# Out:
# company_name             0
# founded_year             1
# company_hq_location      3
# sector                   1
# company_description      0
# founders                24
# investor                86
# amount_usd              12
# funding_round          528
# funding_month            0
# dtype: int64

# %%
isfd_aggregated.head(5)
# Out:
#    company_name founded_year company_hq_location  \
# 0  CollegeDekho       2015.0             Gurgaon
# 1          BOX8       2012.0              Mumbai
# 2         Simpl       2015.0           Bangalore
# 3   8i Ventures       2018.0              Mumbai
# 4     PayGlocal       2021.0           Bangalore
#
#                              sector  \
# 0                        E-learning
# 1                  Food & Beverages
# 2                 Consumer Services
# 3  Venture Capital & Private Equity
# 4                Financial Services
#
#                                  company_description  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
#
#                                          founders  \
# 0                                    Ruchir Arora
# 1                          Anshul Gupta, Amit Raj
# 2                        Nitya, Chaitra Chidanand
# 3                                  Vikram Chachra
# 4  Prachi Dharani, Rohit Sukhija, Yogesh Lokhande
#
#                       investor amount_usd funding_round  funding_month
# 0             Disrupt ADQ, QIC   35000000      Series B             12
# 1                 Tiger Global   40000000           NaN             12
# 2  Valar Ventures, IA Ventures   40000000      Series B             12
# 3                          NaN   50000000           NaN             12
# 4        Sequoia Capital India    4900000      Series A             12

# %% [markdown]
# Fixing funding amount issues

# %%
isfd_aggregated['amount_usd'].value_counts()
# Out:
# Undisclosed     165
# 1000000          51
# 2000000          40
# 10,00,000        33
# 3000000          30
#                ...
# 11,00,00,000      1
# 8,30,00,000       1
# 55,00,000         1
# 35,00,00,000      1
# $39,000,000       1
# Name: amount_usd, Length: 454, dtype: int64

# %%
#Remove the $ from records in the Amount column if present
diff_amounts = set()

def convert_amount(cell):
    if isinstance(cell, float):
        return cell
    
    cell = cell.replace(",", "")
    cell = cell.replace("$", "")
    cell = cell.lower()

    if cell.isalpha():
        diff_amounts.add(cell)
    return cell

isfd_aggregated.loc[:, 'amount_usd'] = isfd_aggregated['amount_usd'].apply(convert_amount)

print(diff_amounts)
# Out:
# {'seed', 'undisclosed', 'upsparks'}
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
len(isfd_aggregated)
# Out:
# 1621

# %%
# testings how the operation above went
isfd_aggregated[~isfd_aggregated['amount_usd'].str.contains('$', na=True)]
# Out:
# Empty DataFrame
# Columns: [company_name, founded_year, company_hq_location, sector, company_description, founders, investor, amount_usd, funding_round, funding_month]
# Index: []

# %% [markdown]
# ## Saving to file for intermediary dataset correction [IMP]

# %%
# commented to make sure files are not overwritten by mistake
# isfd_aggregated.to_csv(dataset_path + '/ISF_Consolidated_Final_2.csv', index=False)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Loading dataset again for programatic cleaning

# %% [markdown]
# Here the Google Sheet. after manual cleaning, was downloaded in the `dataset_path` to and then cleaned programmatically again.

# %%
isfd_clean = pd.read_csv(dataset_path + '/ISF_Consolidated_Final_2_clean.csv')

# %%
isfd_clean.head(2)
# Out:
#    company_name  founded_year company_hq_location            sector  \
# 0  CollegeDekho        2015.0             Gurgaon        E-learning
# 1          BOX8        2012.0              Mumbai  Food & Beverages
#
#                                  company_description                founders  \
# 0  Collegedekho.com is Student’s Partner, Friend ...            Ruchir Arora
# 1                   India's Largest Desi Meals Brand  Anshul Gupta, Amit Raj
#
#            investor amount_usd funding_round  funding_month
# 0  Disrupt ADQ, QIC   35000000      Series B             12
# 1      Tiger Global   40000000           NaN             12

# %%
isfd_clean.columns
# Out:
# Index(['company_name', 'founded_year', 'company_hq_location', 'sector',
#        'company_description', 'founders', 'investor', 'amount_usd',
#        'funding_round', 'funding_month'],
#       dtype='object')

# %% [markdown]
# ## Programatic Cleaning

# %% [markdown]
# Some pointers that we notice from our visual analysis and fixing of the dataset that we exported:
#
#
# We still need some programmatic cleaning of the dataset that need to be scripted:
#
# 1. Lowercase all amounts
# 2. If amount_usd less than \$10,000, then multiply by 1 million to get correct value - We find this to be a trend in some of our files
# 3. Sector column - if second word ends with startup, then get rid of it.
# 4. Sector column - if second word is not capitalized, capitalize it
# 5. Add year column given how the data was loaded. We missed doing this initially and hence have to hack it together to see if this can be added post.
# 6. amount_usd column - some records have $ sig associated with them (This may be fixed already)
# 7. Programatically clean names of cities that we noticed needed mass cleaning else of the one of renaming that we did on google sheets
# 8. Throw out outlier funding values
# 9. Fix funding round data issues (in consistent naming)

# %% [markdown]
# ### 1. Lowercase all amounts

# %%
isfd_clean['amount_usd'] = isfd_clean['amount_usd'].str.lower()

# %% [markdown]
# ### 2. If amount_usd less than \$10,000, then multiply by 1 million to get correct value - We find this to be a trend in some of our files

# %%
isfd_clean['amount_usd'].fillna('unavailable', inplace=True)

# %%
def scale_amount(val):
    try:
        float_val = float(val)
        if float_val < 10000.0:
            return float_val*(10**6)
        else:
            return(float_val)
    except ValueError:
        return val
        

isfd_clean['amount_usd'] = isfd_clean['amount_usd'].apply(scale_amount)

# %%
len(isfd_clean[isfd_clean['amount_usd'].isin(['undisclosed', 'unavailable'])]['amount_usd'])
# Out:
# 1618

# %%
isfd_clean['amount_usd'].str.isalpha().sum()
# Out:
# 1618

# %% [markdown]
# ### 3. Sector column - if second word ends with startup, then get rid of the startup component

# %%
isfd_clean['sector'] = isfd_clean['sector'].replace('(?i)startup', '', regex=True)

# %%
isfd_clean.loc[
    isfd_clean['sector'].str.contains('(?i)startup', regex=True, na=False), 
    'sector'
]
# Out:
# Series([], Name: sector, dtype: object)

# %% [markdown]
# ### 4. Sector column - Title case the words

# %%
isfd_clean['sector'] = isfd_clean['sector'].str.strip()

# %%
isfd_clean['sector'] = isfd_clean['sector'].str.title()

# %%
isfd_clean['sector'].value_counts()
# Out:
# Financial Services                   136
# Fintech                              123
# Edtech                               107
# Information Technology & Services     85
# Healthcare                            65
#                                     ...
# Translation & Localization             1
# Ai Chatbot                             1
# Milk                                   1
# Robotics                               1
# D2C Business                           1
# Name: sector, Length: 248, dtype: int64

# %% [markdown]
# ### 5. Add year column given how the data was loaded. We missed doing this initially and hence have to hack it together to see if this can be added post.

# %% [markdown]
# As the order was preserved across all the operations above, we can confidently add a new column that states the year of these startups getting funded

# %%
# Last two rows of the 2021 table
isfd_2021[-2:]
# Out:
#      company_name  founded_year company_hq_location      sector  \
# 1192   KiranaKart        2020.0              Mumbai  E-commerce
# 1193        Meddo        2018.0             Gurgaon  Healthcare
#
#                                     company_description  \
# 1192  A better model for instant grocery delivery in...
# 1193   Meddo is an end-to-end medical services provider
#
#                            founders                          investor  \
# 1192  Kaivalya Vohra, Aadit Palicha           Global Founders Capital
# 1193                Saurabh Kochhar  growX ventures, Venture Gurukool
#
#      amount_usd funding_round  funding_month
# 1192   7,20,000      Pre-seed              1
# 1193  30,00,000  Pre-series A              1

# %%
# First two rows of the 2021 table
isfd_2022[:2]
# Out:
#     company_name founded_year company_hq_location  \
# 0           Dyte         2020           Bengaluru
# 1  Kirana Bazaar         2018             Gurgaon
#
#                           sector  \
# 0  IT Services and IT Consulting
# 1                  Oline grocery
#
#                                  company_description  \
# 0  Dyte provides the easiest way to add real-time...
# 1  Kirana Bazaar is a neighborhood store network ...
#
#                          founders   investor   amount_usd funding_round  \
# 0                 Felix Lee,Vivan  Multiples  $15,300,000   undisclosed
# 1  Abhishek Halder, Anilesh Yadav  Multiples  $32,800,000   undisclosed
#
#    funding_month
# 0              4
# 1              4

# %%
isfd_clean.loc[1192:1196]
# Out:
#        company_name  founded_year company_hq_location  \
# 1192     KiranaKart        2020.0              Mumbai
# 1193          Meddo        2018.0             Gurgaon
# 1194           Dyte        2020.0           Bengaluru
# 1195  Kirana Bazaar        2018.0             Gurgaon
# 1196          Phool        2017.0              kanpur
#
#                              sector  \
# 1192                     E-Commerce
# 1193                     Healthcare
# 1194  It Services And It Consulting
# 1195                 Online Grocery
# 1196       Enviromental Engineering
#
#                                     company_description  \
# 1192  A better model for instant grocery delivery in...
# 1193   Meddo is an end-to-end medical services provider
# 1194  Dyte provides the easiest way to add real-time...
# 1195  Kirana Bazaar is a neighborhood store network ...
# 1196                    Phool is a biomaterial startup.
#
#                             founders                          investor  \
# 1192   Kaivalya Vohra, Aadit Palicha           Global Founders Capital
# 1193                 Saurabh Kochhar  growX ventures, Venture Gurukool
# 1194                 Felix Lee,Vivan                         Multiples
# 1195  Abhishek Halder, Anilesh Yadav                         Multiples
# 1196                   Ankit Agrawal                         Multiples
#
#        amount_usd funding_round  funding_month
# 1192  unavailable      Pre-seed              1
# 1193  unavailable  Pre-series A              1
# 1194  unavailable   undisclosed              4
# 1195  unavailable   undisclosed              4
# 1196  unavailable   undisclosed              4

# %%
isfd_clean.loc[:1193, 'funding_year'] = 2021
isfd_clean.loc[1194:, 'funding_year'] = 2022
isfd_clean['funding_year'] = isfd_clean['funding_year'].astype(int)

# %%
isfd_clean.loc[1192:1196]
# Out:
#        company_name  founded_year company_hq_location  \
# 1192     KiranaKart        2020.0              Mumbai
# 1193          Meddo        2018.0             Gurgaon
# 1194           Dyte        2020.0           Bengaluru
# 1195  Kirana Bazaar        2018.0             Gurgaon
# 1196          Phool        2017.0              kanpur
#
#                              sector  \
# 1192                     E-Commerce
# 1193                     Healthcare
# 1194  It Services And It Consulting
# 1195                 Online Grocery
# 1196       Enviromental Engineering
#
#                                     company_description  \
# 1192  A better model for instant grocery delivery in...
# 1193   Meddo is an end-to-end medical services provider
# 1194  Dyte provides the easiest way to add real-time...
# 1195  Kirana Bazaar is a neighborhood store network ...
# 1196                    Phool is a biomaterial startup.
#
#                             founders                          investor  \
# 1192   Kaivalya Vohra, Aadit Palicha           Global Founders Capital
# 1193                 Saurabh Kochhar  growX ventures, Venture Gurukool
# 1194                 Felix Lee,Vivan                         Multiples
# 1195  Abhishek Halder, Anilesh Yadav                         Multiples
# 1196                   Ankit Agrawal                         Multiples
#
#        amount_usd funding_round  funding_month  funding_year
# 1192  unavailable      Pre-seed              1          2021
# 1193  unavailable  Pre-series A              1          2021
# 1194  unavailable   undisclosed              4          2022
# 1195  unavailable   undisclosed              4          2022
# 1196  unavailable   undisclosed              4          2022

# %% [markdown]
# ### 6. check for $ and commas on amount_usd column

# %%
isfd_clean[isfd_clean['amount_usd'].str.contains('\$', na=False)]['amount_usd']
# Out:
# 1279    $270,000,000
# 1285     $66,000,000
# 1602      $3,500,000
# Name: amount_usd, dtype: object

# %%
def convert_amount(cell):
    if isinstance(cell, float):
        return cell
    
    if '$' in cell:
        cell = cell.replace(",", "")
        cell = cell.replace("$", "")
        return float(cell)
    else:
        return cell

isfd_clean.loc[:, 'amount_usd'] = isfd_clean['amount_usd'].apply(convert_amount)

# %%
isfd_clean[isfd_clean['amount_usd'].str.contains('\$', na=False)]['amount_usd']
# Out:
# Series([], Name: amount_usd, dtype: object)

# %% [markdown]
# ### 7. Change names of cities to consistent names - Albiet we did clean a lot manually, we wanted to fix some using pandas as well

# %%
isfd_clean['company_hq_location'].replace({
    'Ahemdabad': 'Ahmedabad', 
    'Ahmadabad': 'Ahmedabad'}, inplace=True)

isfd_clean[isfd_clean['company_hq_location'].str.contains('Ah', na=False)].head(2)
# Out:
#     company_name  founded_year company_hq_location  \
# 80    Ninety One        2015.0           Ahmedabad
# 119     Petpooja        2011.0           Ahmedabad
#
#                                 sector  \
# 80                      Consumer Goods
# 119  Information Technology & Services
#
#                                    company_description  \
# 80   Ninety One makes cycles, which the company cla...
# 119  Petpooja is the largest next-generation PoS pl...
#
#                          founders                    investor   amount_usd  \
# 80   Sachin Chopra, Vishal Chopra                A91 Partners  unavailable
# 119    Apurv Patel, Parthiv Patel  Aroa Ventures, GVFL, Udaan  unavailable
#
#     funding_round  funding_month  funding_year
# 80       Series A             12          2021
# 119           NaN             11          2021

# %%
isfd_clean['company_hq_location'].replace({
    'Banglore': 'Bengaluru', 
    'Bangalore': 'Bengaluru',
    'Benglaru': 'Bengaluru'
    }, inplace=True)

isfd_clean[isfd_clean['company_hq_location'].str.contains('B', na=False)].head(2)
# Out:
#   company_name  founded_year company_hq_location              sector  \
# 2        Simpl        2015.0           Bengaluru   Consumer Services
# 4    PayGlocal        2021.0           Bengaluru  Financial Services
#
#                                  company_description  \
# 2  Simpl empowers merchants to build trusted rela...
# 4  PayGlocal is a FinTech solving for global paym...
#
#                                          founders  \
# 2                        Nitya, Chaitra Chidanand
# 4  Prachi Dharani, Rohit Sukhija, Yogesh Lokhande
#
#                       investor   amount_usd funding_round  funding_month  \
# 2  Valar Ventures, IA Ventures  unavailable      Series B             12
# 4        Sequoia Capital India  unavailable      Series A             12
#
#    funding_year
# 2          2021
# 4          2021

# %%
isfd_clean['company_hq_location'].replace({
    'Gurgaon': 'Gurugram', 
    'Gurugram': 'Gurugram'}, inplace=True)

isfd_clean[isfd_clean['company_hq_location'].str.contains('Gur', na=False)].head(2)
# Out:
#    company_name  founded_year company_hq_location                sector  \
# 0  CollegeDekho        2015.0            Gurugram            E-Learning
# 8   PlanetSpark        2017.0            Gurugram  Education Management
#
#                                  company_description  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 8  PlanetSpark is building the World Leader in Co...
#
#                        founders  \
# 0                  Ruchir Arora
# 8  Maneesh Dhooper, Kunal Malik
#
#                                             investor   amount_usd  \
# 0                                   Disrupt ADQ, QIC  unavailable
# 8  Binny Bansal, Deep Kalra, Dr Ashish Gupta, Gok...  unavailable
#
#   funding_round  funding_month  funding_year
# 0      Series B             12          2021
# 8      Series B             12          2021

# %%
isfd_clean['company_hq_location'] = isfd_clean['company_hq_location'].str.title()

# %% [markdown]
# ### 8. Distribution analysis and outlier exclusion

# %%
isfd_clean_2 = isfd_clean.copy(deep=True)

isfd_clean_2['amount_usd'] = isfd_clean_2['amount_usd'].replace({'undisclosed': np.nan, 'unavailable': np.nan})
isfd_clean_2 = isfd_clean_2.dropna(subset=['amount_usd'])
# change entries to floats
isfd_clean_2['amount_usd'] = isfd_clean_2['amount_usd'].astype(float)

# Box Plot
import seaborn as sns
sns.boxplot(isfd_clean_2['amount_usd'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# as you can see that one point is skewing everything up, so we decided to redact it

isfd_clean_2[(isfd_clean_2['amount_usd'] > isfd_clean_2['amount_usd'].quantile(0.9999))]
# Out:
#      company_name  founded_year company_hq_location sector  \
# 1279       Eximpe        2021.0                 NaN    NaN
#
#                                     company_description        founders  \
# 1279  Eximpe is Managing sellers, buyers, processes,...  Arjun Zacharia
#
#                       investor   amount_usd funding_round  funding_month  \
# 1279  Axel Wehr and Rohit M.A.  270000000.0          Seed              4
#
#       funding_year
# 1279          2022

# %%
isfd_clean = isfd_clean[~isfd_clean['company_name'].str.contains('Alteria Capital')]

# %% [markdown]
# ### 9. Funding round data issues

# %% [markdown]
# Convert 'series c' to 'Series C'\
# Change 'Seies A' to 'Series A'\
# Change 'seed' to 'Seed'\
# Change 'Series-D' to 'Series D'\
# Change 'Pre-seed' to 'Pre-Seed'\
# Change 'Post-seed' to 'Post-Seed'\
# Change 'Series B1' to 'Series B'\
# Change 'Series B3' to 'Series B'\
# Change 'Series F1' to 'Series F'\
# Change 'Series F2' to 'Series F'\
# Change 'Seed+' to 'Seed'\
# Change 'Series D1' to 'Series D'\
# Change 'Series A2' to 'Series A'\
# Change 'Series A+' to 'Series A'\
# Change 'Pre-series A' to 'Pre-Series A'\
# Change 'Pre-series A1' to 'Pre-Series A'\
# Change 'pre-series a' to 'Pre-Series A'\
# Change 'Early seed' to 'Seed'\
# Change 'Pre-series B' to 'Pre-Series B'\
# Change 'Seed+' to 'Seed'    \
# Change 'Series': 'Unknown',\
# Change 'Pre-series': 'Unknown',\
# Change np.NaN: 'Unknown'

# %%
# to change names and data points in funding_round
dict = {
    'series c':'Series C', 
    'Seies A':'Series A', 
    'seed':'Seed', 
    'Series-D':'Series D', 
    'Pre-seed':'Pre-Seed', 
    'Post-seed':'Post-Seed', 
    'Series B1':'Series B', 
    'Series B3':'Series B', 
    'Pre-series B':'Pre-Series B',
    'Series F1':'Series F',
    'Series F2':'Series F',
    'Series D1':'Series D',
    'Series A2':'Series A',
    'Series A+':'Series A',
    'Pre-series A':'Pre-Series A',
    'Pre-series A1':'Pre-Series A',
    'pre-series a':'Pre-Series A',
    'Early seed':'Seed',
    'Seed+':'Seed',
    'Series': 'Unknown',
    'Pre-series': 'Unknown',
    np.NaN: 'Unknown'
}

isfd_clean.replace({"funding_round": dict},inplace=True)
isfd_clean.head(20)
# Out:
#         company_name  founded_year company_hq_location  \
# 0       CollegeDekho        2015.0            Gurugram
# 1               BOX8        2012.0              Mumbai
# 2              Simpl        2015.0           Bengaluru
# 3        8i Ventures        2018.0              Mumbai
# 4          PayGlocal        2021.0           Bengaluru
# 5            Curefit        2016.0           Bengaluru
# 6          Pocket FM        2018.0           Bengaluru
# 7        CHARGE+ZONE        2018.0            Vadodara
# 8        PlanetSpark        2017.0            Gurugram
# 9         LenDenClub        2015.0              Mumbai
# 10         CometChat        2009.0              Mumbai
# 11          AgroStar        2013.0                Pune
# 12           Bizongo        2015.0              Mumbai
# 13  Probus Insurance        2002.0              Mumbai
# 14          MoEngage        2014.0           Bengaluru
# 15          CloudSEK        2015.0           Bengaluru
# 16   Exponent Energy        2020.0           Bengaluru
# 17          Trinkerr        2021.0           Bengaluru
# 18             Zorro        2021.0            Gurugram
# 19     Ultraviolette        2021.0           Bengaluru
#
#                                sector  \
# 0                          E-Learning
# 1                    Food & Beverages
# 2                   Consumer Services
# 3    Venture Capital & Private Equity
# 4                  Financial Services
# 5          Health, Wellness & Fitness
# 6                                 Ott
# 7                          Automotive
# 8                Education Management
# 9                  Financial Services
# 10                  Computer Software
# 11                           Agritech
# 12  Information Technology & Services
# 13                          Insurance
# 14                           Software
# 15        Computer & Network Security
# 16                         Automotive
# 17                    Capital Markets
# 18                     Social Network
# 19                         Automotive
#
#                                   company_description  \
# 0   Collegedekho.com is Student’s Partner, Friend ...
# 1                    India's Largest Desi Meals Brand
# 2   Simpl empowers merchants to build trusted rela...
# 3   8i is a Mumbai & Bangalore based early stage f...
# 4   PayGlocal is a FinTech solving for global paym...
# 5                         Tata Digital-backed Curefit
# 6   Pocket FM lets users discover and enjoy the gr...
# 7   CHARGE+ZONE is a tech-driven EV Charging infra...
# 8   PlanetSpark is building the World Leader in Co...
# 9   P2P lending platform delivering high returns o...
# 10  Voice, video & text chat SDKs, APIs & Plugins ...
# 11  AgroStar is one of India’s foremost AgTech sta...
# 12  Bizongo is India’s largest B2B platform for ma...
# 13  Probus Insurance is a leading InsurTech platfo...
# 14  Insights-led customer engagement platform for ...
# 15  AI-powered Digital Risk Monitoring platform th...
# 16  Simplifying energy for EVs by building a Flexi...
# 17  Trinkerr is India's first social trading platf...
# 18               Pseudonymous social network platform
# 19  Create and Inspire the future of sustainable u...
#
#                                           founders  \
# 0                                     Ruchir Arora
# 1                           Anshul Gupta, Amit Raj
# 2                         Nitya, Chaitra Chidanand
# 3                                   Vikram Chachra
# 4   Prachi Dharani, Rohit Sukhija, Yogesh Lokhande
# 5                             Mukesh Bansal, Ankit
# 6          Rohan, Nishanth Srinivas, Prateek Dixit
# 7                                Kartikey Hariyani
# 8                     Maneesh Dhooper, Kunal Malik
# 9                       Bhavin Patel, Dipesh Karki
# 10                                Anuj, Anant Garg
# 11                         Shardul, Sitanshu Sheth
# 12         Sachin Agrawal, Aniket Deb, Ankit Tomar
# 13                                    Rakesh goyal
# 14                 Raviteja Dodda, Yashwanth Kumar
# 15                                      Rahul Sasi
# 16                     Arun Vinayak, Sanjay Byalal
# 17                 Manvendra Singh, Gaurav Agarwal
# 18   Jasveer Singh, Abhishek Asthana, Deepak Kumar
# 19             Subramaniam Narayan, Niraj Rajmohan
#
#                                              investor   amount_usd  \
# 0                                    Disrupt ADQ, QIC  unavailable
# 1                                        Tiger Global  unavailable
# 2                         Valar Ventures, IA Ventures  unavailable
# 3                                                 NaN  unavailable
# 4                               Sequoia Capital India  unavailable
# 5                                              Zomato  unavailable
# 6   Lightspeed, Times Group, Tanglin Venture Partners  unavailable
# 7                                   Venture Catalysts  unavailable
# 8   Binny Bansal, Deep Kalra, Dr Ashish Gupta, Gok...  unavailable
# 9   Tuscan Ventures, Ohm Stock Brokers, Artha Vent...  unavailable
# 10                               Signal Peak Ventures  unavailable
# 11                         Evolvence, Hero Enterprise  unavailable
# 12                                       Tiger Global  unavailable
# 13             BlueOrchard Impact Investment Managers  unavailable
# 14                                  Steadview Capital  unavailable
# 15                                MassMutual Ventures  unavailable
# 16                                        YourNest VC  unavailable
# 17                                        Accel India  unavailable
# 18  Vijay Shekhar Sharma, Ritesh Agarwal, Ankiti Bose  unavailable
# 19                                    TVS Motor, Zoho  unavailable
#
#    funding_round  funding_month  funding_year
# 0       Series B             12          2021
# 1        Unknown             12          2021
# 2       Series B             12          2021
# 3        Unknown             12          2021
# 4       Series A             12          2021
# 5        Unknown             12          2021
# 6       Series B             12          2021
# 7        Unknown             12          2021
# 8       Series B             12          2021
# 9       Series A             12          2021
# 10      Series A             12          2021
# 11      Series D             12          2021
# 12      Series D             12          2021
# 13       Unknown             12          2021
# 14      Series D             12          2021
# 15      Series A             12          2021
# 16  Pre-Series A             12          2021
# 17      Series A             12          2021
# 18          Seed             12          2021
# 19      Series C             12          2021

# %% [markdown]
# # Save for the last time!

# %%
isfd_clean.to_csv(dataset_path + '/ISF_Consolidated_Final_3.csv', index=False)

# %% [markdown]
# we should low-key publish this dataset on kaggle. super cool for open source EDAs
